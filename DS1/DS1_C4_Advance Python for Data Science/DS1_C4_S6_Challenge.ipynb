# %%
import pandas as pd

# %%
Data = pd.read_csv('housing.csv')

# %%
Data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # TASK1

# %%
A = Data[(Data['LotArea']>=6000)& (Data['LotConfig']=='Corner')]

# %%
A.reset_index()
# Out:
#      index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0        3     4          70       RL         60.0     9550   Pave   NaN
# 1        7     8          60       RL          NaN    10382   Pave   NaN
# 2        9    10         190       RL         50.0     7420   Pave   NaN
# 3       14    15          20       RL          NaN    10920   Pave   NaN
# 4       15    16          45       RM         51.0     6120   Pave   NaN
# ..     ...   ...         ...      ...          ...      ...    ...   ...
# 236   1407  1408          20       RL          NaN     8780   Pave   NaN
# 237   1413  1414          20       RL         88.0    10994   Pave   NaN
# 238   1420  1421          60       RL         90.0    11700   Pave   NaN
# 239   1428  1429          30       RM         60.0     7200   Pave   NaN
# 240   1429  1430          20       RL          NaN    12546   Pave   NaN
#
#     LotShape LandContour  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# # TASK2

# %%
B= Data[(Data['BldgType'] =='1Fam') & (Data['HouseStyle'] =='1Story') & (Data['LandContour'] =='Lvl')]
B.reset_index()
# Out:
#      index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0        1     2          20       RL         80.0     9600   Pave   NaN
# 1        6     7          20       RL         75.0    10084   Pave   NaN
# 2       10    11          20       RL         70.0    11200   Pave   NaN
# 3       12    13          20       RL          NaN    12968   Pave   NaN
# 4       13    14          20       RL         91.0    10652   Pave   NaN
# ..     ...   ...         ...      ...          ...      ...    ...   ...
# 540   1453  1454          20       RL         90.0    17217   Pave   NaN
# 541   1454  1455          20       FV         62.0     7500   Pave  Pave
# 542   1456  1457          20       RL         85.0    13175   Pave   NaN
# 543   1458  1459          20       RL         68.0     9717   Pave   NaN
# 544   1459  1460          20       RL         75.0     9937   Pave   NaN
#
#     LotShape LandContour  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# # TASK3

# %%
C = Data[((Data['MSZoning']=='RH') | (Data['MSZoning']=='RM')) & (Data['BldgType']=='Twnhs')]
a=C.groupby('MSSubClass')['Id'].count()
print (a.idxmax(),": 1-STORY PUD (Planned Unit Development) - 1946 & NEWER} were the hot selling property in California") 
c= C[C['MSSubClass']==a.idxmax()]
c
# Out:
# 160 : 1-STORY PUD (Planned Unit Development) - 1946 & NEWER} were the hot selling property in California
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 145    146         160       RM         24.0     2522   Pave   NaN      Reg
# 193    194         160       RM         24.0     2522   Pave   NaN      Reg
# 225    226         160       RM         21.0     1680   Pave   NaN      Reg
# 227    228         160       RM         21.0     1869   Pave   NaN      Reg
# 232    233         160       RM         21.0     1680   Pave   NaN      Reg
# 363    364         160       RM         21.0     1680   Pave   NaN      Reg
# 430    431         160       RM         21.0     1680   Pave   NaN      Reg
# 500    501         160       RM         21.0     1890   Pave   NaN      Reg
# 599    600         160       RM         24.0     1950   Pave   NaN      Reg
# 655    656         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %% [markdown]
# # TASK4

# %%
D= Data[(Data['BedroomAbvGr'] >=3) & (Data['TotalBsmtSF'] !=0)  & (Data['Exterior1st'] =='CemntBd') & (Data['Exterior2nd'] =='CmentBd')]
D.reset_index()
# Out:
#     index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0      23    24         120       RM         44.0     4224   Pave   NaN
# 1     108   109          50       RM         85.0     8500   Pave   NaN
# 2     196   197          20       RL         79.0     9416   Pave   NaN
# 3     261   262          60       RL         69.0     9588   Pave   NaN
# 4     278   279          20       RL        107.0    14450   Pave   NaN
# 5     304   305          75       RM         87.0    18386   Pave   NaN
# 6     305   306          20       RL         80.0    10386   Pave   NaN
# 7     316   317          60       RL         94.0    13005   Pave   NaN
# 8     344   345         160       RM         36.0     2592   Pave   NaN
# 9     349   350          60       RL         56.0    20431   Pave   NaN
# 10    357   358         120       RM         44.0     4224   Pave   NaN
# 11    377   378          60       FV        102.0    11143   Pave   NaN
# ...

# %% [markdown]
# # TASK5

# %%
E= Data[(Data['GarageArea'] >=500 )]
E.reset_index()
# Out:
#      index    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0        0     1          60       RL         65.0     8450   Pave   NaN
# 1        2     3          60       RL         68.0    11250   Pave   NaN
# 2        3     4          70       RL         60.0     9550   Pave   NaN
# 3        4     5          60       RL         84.0    14260   Pave   NaN
# 4        6     7          20       RL         75.0    10084   Pave   NaN
# ..     ...   ...         ...      ...          ...      ...    ...   ...
# 630   1444  1445          20       RL         63.0     8500   Pave   NaN
# 631   1447  1448          60       RL         80.0    10000   Pave   NaN
# 632   1451  1452          20       RL         78.0     9262   Pave   NaN
# 633   1452  1453         180       RM         35.0     3675   Pave   NaN
# 634   1456  1457          20       RL         85.0    13175   Pave   NaN
#
#     LotShape LandContour  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
import mysql.connector as sql

# %%
from sqlalchemy import create_engine

# %%
# Create SQLAlchemy engine to connect to MySQL Database
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
.format(host='localhost', user='root',pw='mysql',db='challange'))

# %%
A.to_sql('task_one', engine, index=False) # employee details is the name of the table 
B.to_sql('task_two', engine, index=False) # employee details is the name of the table 
c.to_sql('task_three', engine, index=False) # employee details is the name of the table 
D.to_sql('task_four', engine, index=False) # employee details is the name of the table 
E.to_sql('task_five', engine, index=False) # employee details is the name of the table
# Out:
# 635
