# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     1) 3 men out of 6 and 2 women out of 4
#
#     6c3 * 4c2 = 120
#
#     2) Only men
#
#     6c5 = 6
#
#     3) Mojorty of women
#
#     which means max two men are allowed
#     a = 6c2 * 4c3 = 15*4 = 60
#     b = 6c1 * 4c4 = 6 * 1 = 6
#     Mojorty of women = 66 ways
#
# Hence option 2 is correct

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Player can have five card out of pack of 52 so the possible combination that he can have is 52C5 = 2,598,960
#
#  Hence the correct option is 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     To get the three costestansts that we can award has to be in a order so we use
#     permutation without repetation because a person can not have two awards
#
#     8p3 = 8!/(8-3)! = 336
#
# Hence correct option is 2

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#     a = Total number of ways 15 student can sit = n! = 15!
#     b = Total number of ways 15 student can sit and Jenny and David = (n-1)! = 14!*2
#     Answer = 15! - 14!*2! = D

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     1-3, 2-6, 3-1, 6-2 = fours combination
#     Sample space is 36 because we have two dice
#     4/36 = 1/9
# Hence Correct Answer is 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     For this to be solved we used permutation because there is order in which word can arrange
#     first we calculate permutation for consonant and then for Vowels
#     7c3 * 4c2 = 210
#     5! = 120 # in the way 5 ways can sit on a table.
#
# Hence 25200 words can be formed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     if ava is already owner of the society then we have have 11 member left and committee need 4 for more member
#     so to calculate this we use combination
#     11C4 = 330
# Hence in 330 ways a communittee can be formed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     A pack of 25 bulbs contains 25% defective bulbs
#     ∴ defective bulbs  = 6
#     Total Bulbs = 25
#     after after drawn onegood bulb , Total bulbs left = 24
#     Probabilty = Total number of possible events/ total number of outcomes
#     P = 24-6/24 i.e 18/24
# Hence correct answer is 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Van = 50
#     Car = 80
#     lorries = 150 - (80+50) = 20
#
#     a) Van leaving first
#
#         50/150 = 1/3
#
#     b) lorry leaving first
#
#         20/150  = 2/15
#
#     c-1) Car leaving second  = car not leaving 1st * car leaving second
#
#         = (70/150)*(80/149) =560/2235
#
#     c-2) Car leaving second  = car leaving second
#
#         = (80/149)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     a) Total number of student = 30
#        two left handed student in 8 class
#        so there for probability is
#        8/30 i.e 4/15
#
#        Hence the correct amswer is 4/15
#
#     b) To calculate this first we find the probality of every class that has more then
#         3 left handed student then we multiply them
#
#        (5/30)*(12/30)*(2/30) = 1/225

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Length of sq = 2x
#     Area of sq=  4x^2
#     height of triangle = x
#     Area of triangle = (1/2)x^2
#
#     Probability of getting a point in triangle = Probabilty of point on Sq - Probabilty of point triangle
#                                              =1 - (Area of sq - Area of triangle)/Area of square
#                                              = 1/8
# Hence the correct answer is b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     1) Equal to one = Zero
#     2) Equal to 4 = 1+3, 2+2, 2+2, 3+1
#         sample space = 4
#         Probability = 4/36 = 1/9
#     3) Less than 13 = One

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) Total even numbers between 1 and 20 = 10
#     probability = 10/20 = 1/2
#
# 2) Total Numbers divisible by 3 = 6
#     probability = 6/20 = 3/10
#
# 3) Total Prime numbers between 1 and 20 = 8
#     probability = 8/20 = 2/5
#
# 4) Total Numbers divisible by 5 = 4
#     probability = 4/20 = 1/5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Probability of a sum of 11: 27/216
#     Probability of a sum of 12: 25/216
#
#     Hence sum 11 occur more probably
