# %%
import random
print("------------------------------------------3rd grade Mathmatics Quiz-------------------------------------------------")
print()
print()

#################------------------------------------1----############################--------------------


prize =1
while prize!=3:
    prize =0
    r1q1=random.randrange(1,10,1)
    r2q1=random.randrange(1,10,1)
    print("1) What is the sum of {0} and {1}: ".format(r1q1,r2q1))
    list1 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),r1q1+r2q1]
    random.shuffle(list1)
    print('a:' ,list1[0])
    print('b:' ,list1[1])
    print('c:' ,list1[2])
    print('d:' ,list1[3])
    dict = {'a':list1[0],'b':list1[1],'c':list1[2],'d':list1[3]}
    print()
    
    QUE1= str(input("Enter Correct Option: "))
    Ans = dict[QUE1]
    
    if Ans==r1q1+r2q1:
        prize=prize+1
    else:
        pass
    
#################-------------------------------------2---############################--------------------


    r1q2=random.randrange(1,10,1)
    r2q2=random.randrange(1,10,1)
    print("2) What is the product of {0} and {1}: ".format(r1q2,r2q2))

    list2 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),r1q2*r2q2]
    random.shuffle(list1)
    print('a:' ,list2[0])
    print('b:' ,list2[1])
    print('c:' ,list2[2])
    print('d:' ,list2[3])
    dict2 = {'a':list2[0],'b':list2[1],'c':list2[2],'d':list2[3]}
    print()
    
    QUE2 = str(input("Enter Correct Option: "))
    Ans2 = dict2[QUE2]
    
    if Ans2==r1q2*r2q2:
        prize=prize+1
    else:
        pass
    
    
#####################----------------------------------3---#######################------------------     
    r1q3=random.randrange(40,100,2)
    QUE3 = print("3) What is the 10% of {0}: ".format(r1q3))
    per =10/100*r1q3
    list3 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),per]
    random.shuffle(list3)
    print('a:' ,list3[0])
    print('b:' ,list3[1])
    print('c:' ,list3[2])
    print('d:' ,list3[3])
    dict3 = {'a':list3[0],'b':list3[1],'c':list3[2],'d':list3[3]}
    print()
    
    QUE3 = str(input("Enter Correct Option: "))
    Ans3 = dict3[QUE3]
    
    if Ans3==per:
        prize=prize+1
    else:
        pass

#########-----------------------------4---#####################-----------------------------------
    r1q4=random.randrange(1,90)
    print("4) What is the remainder of {0} when divisible by 2: ".format(r1q4))
    mod = r1q4%2
    list4 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),mod]
    random.shuffle(list4)

    print('a:' ,list4[0])
    print('b:' ,list4[1])
    print('c:' ,list4[2])
    print('d:' ,list4[3])
    dict4 = {'a':list4[0],'b':list4[1],'c':list4[2],'d':list4[3]}
    print()

    QUE4 = str(input("Enter Correct Option: "))
    Ans4 = dict4[QUE4]
    
    if Ans4==mod:
        prize=prize+1
    else:
        pass

#########################-----------------------------5----#############----------------------------
    r1q5=random.randrange(1,10)
    print("5) What is the square of {0}: ".format(r1q5))
    sq = r1q5**2
    
    list5 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),sq]
    random.shuffle(list5)
    print('a:' ,list5[0])
    print('b:' ,list5[1])
    print('c:' ,list5[2])
    print('d:' ,list5[3])
    dict5 = {'a':list5[0],'b':list5[1],'c':list5[2],'d':list5[3]}
    print()
    
    QUE5 = str(input("Enter Correct Option: "))
    Ans5 = dict5[QUE5]
    if Ans5==sq:
        prize=prize+1
    else:
        pass

##################------------------------------------6------###################

    r1q6=random.randrange(1,10)
    print("6) What is the square root of {0}: ".format(r1q6))
    sqr = r1q6**0.5
    
    list6 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),sqr]
    random.shuffle(list6)
    print('a:' ,list6[0])
    print('b:' ,list6[1])
    print('c:' ,list6[2])
    print('d:' ,list6[3])
    dict6 = {'a':list6[0],'b':list6[1],'c':list6[2],'d':list6[3]}
    print()
    
    QUE6 = str(input("Enter Correct Option: "))
    Ans6 = dict6[QUE6]
    
    if Ans6==sqr:
        prize=prize+1
    else:
        pass
    
##################------------------------------------7------###################

    r1q7=random.randrange(1,10)
    print("7) What is the area of circle where radius is {0}: ".format(r1q7))
    area = 3.14*(r1q6**2)
    
    list7 =[random.randrange(1,90),random.randrange(1,90),random.randrange(1,90),area]
    random.shuffle(list7)
    print('a:' ,list7[0])
    print('b:' ,list7[1])
    print('c:' ,list7[2])
    print('d:' ,list7[3])
    dict7 = {'a':list7[0],'b':list7[1],'c':list7[2],'d':list7[3]}
    print()
    
    QUE7 = str(input("Enter Correct Option: "))
    Ans7 = dict7[QUE7]
    
    if Ans7==area:
        prize=prize+1
    else:
        pass

##################-----------------------------------8-------###################

    r2q8=random.randrange(1,20)
    r2q8=random.randrange(1,20)
    print("8) What is the area of rectangle where length is {0} and Width is {1}: ".format(r2q8,r2q8))
    arear = r2q8*r2q8
    list8 =[random.randrange(20,90),random.randrange(20,90),random.randrange(20,90),arear]
    random.shuffle(list8)
    print('a:' ,list8[0])
    print('b:' ,list8[1])
    print('c:' ,list8[2])
    print('d:' ,list8[3])
    dict8 = {'a':list7[0],'b':list7[1],'c':list7[2],'d':list7[3]}
    print()
    
    QUE8 = str(input("Enter Correct Option: "))
    Ans8 = dict8[QUE8]
    
    if Ans8==arear:
        prize=prize+1
    else:
        pass
    
##################----------------------------------9--------###################

    r1q9=random.randrange(1,20)
    print("9) What is the area of square where length of side is {0}: ".format(r1q9))
    areas = r1q9**2
    list9=[random.randrange(20,90),random.randrange(20,90),random.randrange(20,90),areas]
    random.shuffle(list9)
    print('a:' ,list9[0])
    print('b:' ,list9[1])
    print('c:' ,list9[2])
    print('d:' ,list9[3])
    dict9 = {'a':list9[0],'b':list9[1],'c':list9[2],'d':list9[3]}
    print()
    
    QUE9 = str(input("Enter Correct Option: "))
    Ans9 = dict9[QUE9]
    
    if Ans9==areas:
        prize=prize+1
    else:
        pass
    
##################----------------------------------10--------###################

    r1q10=random.randrange(1,20)
    print("10) What is the perimeter of square where length of side is {0}: ".format(r1q10))
    paras = r1q10*4
    list10=[random.randrange(20,90),random.randrange(20,90),random.randrange(20,90),paras]
    random.shuffle(list10)
    print('a:' ,list10[0])
    print('b:' ,list10[1])
    print('c:' ,list10[2])
    print('d:' ,list10[3])
    dict10 = {'a':list10[0],'b':list10[1],'c':list10[2],'d':list10[3]}
    print()
    
    QUE10 = str(input("Enter Correct Option: "))
    Ans10 = dict10[QUE10]
    
    if Ans10==paras:
        prize=prize+1
    else:
        pass
    
    
    
    print()
    print()
    

    print('Your Score is: ', prize)
    print()
    print()
    
    print('Correct Answers are')
    print("What is the sum of {0} and {1}:   {2}".format(r1q1,r2q1,(r1q1+r2q1)))
    print("What is the product of {0} and {1}:   {2} ".format(r1q2,r2q2,(r1q2*r2q2)))
    print("What is the 10% of {0}:   {1}".format(r1q3,per))
    print("What is the remainder of {0} when divisible by 2:     {1}".format(r1q4,mod))
    print("What is the square of {0}:    {1}".format(r1q5, sq))
    print("6) What is the square root of {0}:    {1}".format(r1q6,sqr))
    print("7) What is the area of circle where radius is {0}:     {1}".format(r1q7,area))
    print("8) What is the area of rectangle where length is {0} and Width is {1}:      {2}".format(r2q8,r2q8,arear))
    print("9) What is the area of square where length of side is {0}:    {1}".format(r1q9,areas))
    print("10) What is the perimeter of square where length of side is {0}:    {1}".format(r1q10,paras))


        
    
    a = str(input("Do you want to play again?    (Yes/No)")).lower()
    if a=='yes':
        continue
    else:
        
        print("Thanks for playing")
        break
# Out:
# ------------------------------------------3rd grade Mathmatics Quiz-------------------------------------------------
#
#
# 1) What is the sum of 9 and 3:
# a: 12
# b: 58
# c: 46
# d: 5
#
# Enter Correct Option: a
# 2) What is the product of 2 and 7:
# a: 61
# b: 65
# c: 72
# d: 14
#
# Enter Correct Option: d
# 3) What is the 10% of 58:
# a: 47
# b: 5.800000000000001
# c: 38
# d: 47
#
# Enter Correct Option: b
# 4) What is the remainder of 16 when divisible by 2:
# a: 32
# b: 0
# c: 53
# d: 36
#
# Enter Correct Option: b
# 5) What is the square of 4:
# a: 16
# b: 5
# c: 16
# d: 6
